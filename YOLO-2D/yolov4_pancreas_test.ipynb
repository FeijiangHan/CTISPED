# %%
#PANCREAS DETECTION

#Clone the darknet YOLOv3 directory.
! git clone https://github.com/AlexeyAB/darknet.git


#Load the Drive helper and mount
from google.colab import drive

#This will prompt for authorization.
drive.mount('/content/drive')

#Create a symbolic link, in order no to be able to save weights on drive. Otherwise it gives an error. 
# !ln -s /content/drive/My\ Drive /content/mydrive

#After executing the cell above, Drive
#files will be present in "/content/drive/My Drive".
# !ls "/content/mydrive/Yolo_pancreas"


#Remove the existing Makefile
# !rm -rf /content/darknet/Makefile
#Remove the data folder
# !rm -rf /content/darknet/data
#Remove the backup folder
# !rm -rf /content/darknet/backup
#Remove some source files (will be replaced with the updated)
#!rm -rf /content/darknet/src/detector.c
#!rm -rf /content/darknet/src/image.c

#Upload the updated Makefile
# !cp /content/mydrive/Yolo_pancreas/Makefile /content/darknet
#Upload the cfg model
# !cp /content/mydrive/Yolo_pancreas/cfg/yolov4-obj.cfg /content/darknet/cfg
#Upload the backup folder (containing the model weights)
# !cp -r /content/mydrive/Yolo_pancreas/backup /content/darknet
#Upload the updated data folder (containing the test images)
# !cp -r /content/mydrive/Yolo_pancreas/data /content/darknet
#Upload the python script for showing the predections
#!cp -r /content/mydrive/Yolo_pancreas/YOLO_show_prediction_test_data.py /content/darknet
# !cp -r /content/mydrive/Yolo_pancreas/YOLO_get_BB_in_txt_of_test_data.py /content/darknet
# !cp -r /content/mydrive/Yolo_pancreas/YOLO_show_prediction_test_data_AND_real_label.py /content/darknet

#Upload the updated sources files to crop the Bounding Box.
#!cp /content/mydrive/Yolo_pancreas/detector.c /content/darknet/src/
#!cp /content/mydrive/Yolo_pancreas/image.c /content/darknet/src/
print("uploading done!")

#Unzip the testing images
print("unzipping..")
# !unzip -uq "/content/mydrive/Yolo_pancreas/data/input.zip" -d "/content/darknet/data/"
# !unzip -uq "/content/mydrive/Yolo_pancreas/data/labels.zip" -d "/content/darknet/data/"

print("unzipping done!")
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 13658, done.
# remote: Total 13658 (delta 0), reused 0 (delta 0), pack-reused 13658
# Receiving objects: 100% (13658/13658), 12.24 MiB | 11.74 MiB/s, done.
# Resolving deltas: 100% (9317/9317), done.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# backup		   Makefile
# cfg		   YOLO_get_BB_in_txt_of_test_data.py
# darknet53.conv.74  YOLO_show_prediction_test_data_AND_real_label.py
# data		   YOLO_show_prediction_test_data.py
# ...

# %%
# !unzip -uq "/content/darknet/data/input.zip" -d "/content/darknet/data/"

# %%
#The Makefile is edited according to: https://github.com/AlexeyAB/darknet#how-to-compile-on-linux-using-make

#Run make command for newly edited Makefile.
# %cd /content/darknet/
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ...

# %%
# !make clean
# Out:
# rm -rf ./obj/image_opencv.o ./obj/http_stream.o ./obj/gemm.o ./obj/utils.o ./obj/dark_cuda.o ./obj/convolutional_layer.o ./obj/list.o ./obj/image.o ./obj/activations.o ./obj/im2col.o ./obj/col2im.o ./obj/blas.o ./obj/crop_layer.o ./obj/dropout_layer.o ./obj/maxpool_layer.o ./obj/softmax_layer.o ./obj/data.o ./obj/matrix.o ./obj/network.o ./obj/connected_layer.o ./obj/cost_layer.o ./obj/parser.o ./obj/option_list.o ./obj/darknet.o ./obj/detection_layer.o ./obj/captcha.o ./obj/route_layer.o ./obj/writing.o ./obj/box.o ./obj/nightmare.o ./obj/normalization_layer.o ./obj/avgpool_layer.o ./obj/coco.o ./obj/dice.o ./obj/yolo.o ./obj/detector.o ./obj/layer.o ./obj/compare.o ./obj/classifier.o ./obj/local_layer.o ./obj/swag.o ./obj/shortcut_layer.o ./obj/activation_layer.o ./obj/rnn_layer.o ./obj/gru_layer.o ./obj/rnn.o ./obj/rnn_vid.o ./obj/crnn_layer.o ./obj/demo.o ./obj/tag.o ./obj/cifar.o ./obj/go.o ./obj/batchnorm_layer.o ./obj/art.o ./obj/region_layer.o ./obj/reorg_layer.o ./obj/reorg_
# ...

# %%
# %cd /content/darknet/
# Out:
# /content/darknet

# %%
#Test the model
#! python3 YOLO_show_prediction_test_data.py
! python3 YOLO_get_BB_in_txt_of_test_data.py
#! python3 YOLO_show_prediction_test_data_AND_real_label

#Copy the predicted images to the drive.
# !cp -r /content/darknet/data/output /content/mydrive/Yolo_pancreas/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   14 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   15 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   16 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 104 x 104 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   19 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 104 x 104 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   22 route  21 12 	                           ->  104 x 104 x 128
#   23 conv    128       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x 128 0.354 BF
#   24 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
# ...

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
